# %% [markdown]
# # Energy Efficiency Benchmark\n\nComprehensive energy efficiency analysis for 2025 LLM models on Firmus AI Cloud H200 infrastructure.\n\n## Objectives\n- Measure real-time GPU power consumption\n- Calculate energy per token (J/token) for apples-to-apples comparison\n- Benchmark across all configured 2025 models\n- Generate efficiency rankings and visualizations

# %%
import sys
sys.path.append('../src')

import torch
import yaml
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from energy_monitor import H200EnergyMonitor
# from energy_efficient_inference import EnergyEfficientInference  # Commented out - not used in this notebook

# Set plot style
sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = (12, 6)
# Out:
# /home/ubuntu/firmus-model-evaluation/venv/lib/python3.12/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %% [markdown]
# ## Load Model Configuration

# %%
# Load models from config\nconfig_path = Path('../configs/models.yaml')\nwith open(config_path) as f:\n    config = yaml.safe_load(f)\n\nmodels = config['models']\nprint(f'Loaded {len(models)} models for benchmarking')
